# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.sort_values(by="tip",ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# ..          ...    ...     ...    ...   ...     ...   ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.sort_values(by="time")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 147       11.87  1.63  Female     No  Thur   Lunch     2
# 148        9.78  1.73    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 74        14.73  2.20  Female     No   Sat  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.sort_values(by="total_bill",ascending=False).head(5)
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3

# %%
tips.sort_values(by="size",ascending=False).head(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 143       27.05  5.0  Female     No  Thur   Lunch     6
# 156       48.17  5.0    Male     No   Sun  Dinner     6
# 125       29.80  4.2  Female     No  Thur   Lunch     6
# 141       34.30  6.7    Male     No  Thur   Lunch     6
# 185       20.69  5.0    Male     No   Sun  Dinner     5

# %%
tips.sort_values(by=["total_bill","tip"]).head(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2

# %% [markdown]
# ### sort based on specific colums

# %%
# sort by size column
tips.sort_values(by="size")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 125       29.80  4.20  Female     No  Thur   Lunch     6
#
# [244 rows x 7 columns]

# %%
# sort by size column in descending order
tips.sort_values(by="size",ascending=False)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# ..          ...   ...     ...    ...   ...     ...   ...
# 105       15.36  1.64    Male    Yes   Sat  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 82        10.07  1.83  Female     No  Thur   Lunch     1
#
# [244 rows x 7 columns]

# %%
## sort particular column
tips["size"].sort_values(ascending=False)
# Out:
# 143    6
# 156    6
# 125    6
# 141    6
# 185    5
#       ..
# 105    2
# 67     1
# 222    1
# 111    1
# 82     1
# Name: size, Length: 244, dtype: int64

# %% [markdown]
# ## astype()

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips["tip"]=tips["tip"].astype("int")

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip              int32
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ##### Pandas DataFrame.count()
#
# The Pandas count() is defined as a method that is used to count the number of non-NA cells for each column or row. It is also suitable to work with the non-floating data.
#
# ##### Syntax:
#
# DataFrame.count(axis=0, level=None, numeric_only=False)
#
# Parameters:
#
#
# axis: {0 or 'index', 1 or 'columns'}, default value 0
# 0 or 'index' is used for row-wise, whereas 1 or 'columns' is used for column-wise.
#
# level: int or str
# It is an optional parameter. If an axis is hierarchical, it counts along with the particular level and collapsing into the DataFrame.
#
# numeric_only: bool, default value False
# It only includes int, float, or Boolean data.

# %%
import pandas as pd  
import numpy as np  
info = pd.DataFrame({"Person":["Parker", "Smith", "William", "John"],"Age": [27., 29, np.nan, 32] }) 
info
# Out:
#     Person   Age
# 0   Parker  27.0
# 1    Smith  29.0
# 2  William   NaN
# 3     John  32.0

# %%
info.count()
# Out:
# Person    4
# Age       3
# dtype: int64

# %%
info.count(axis=1)
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# dtype: int64

# %%
info.count(axis=0)
# Out:
# Person    4
# Age       3
# dtype: int64

# %% [markdown]
# ##### The cut() method is invoked when you need to segment and sort the data values into bins.
#
#
# ###### It is used to convert a continuous variable to a categorical variable.
#  It can also segregate an array of elements into separate bins.
#
# ##### The method only works for the one-dimensional array-like objects.
#
# ####### If we have a large set of scalar data and perform some statistical analysis on it, we can use the cut() method.
#
# Syntax:
# pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicate

# %%
#Let’s say we have an array of 10 random numbers from 1 to 100 and we wish to separate data into 5 bins of (1,20] , (20,40] , (40,60] ,  (60,80] , (80,100] .


 
df=pd.DataFrame({'Age': np.random.randint(1, 100, 10)})
df
# Out:
#    Age
# 0   81
# 1   61
# 2   54
# 3   68
# 4   18
# 5   11
# 6   92
# 7   31
# 8   57
# 9   42

# %%
df["category"]=pd.cut(x=df['Age'], bins=[1, 20, 40, 60,80, 100])   # this command creates bins accross the numbers correspondingly

df
# Out:
#    Age   category
# 0   81  (80, 100]
# 1   61   (60, 80]
# 2   54   (40, 60]
# 3   68   (60, 80]
# 4   18    (1, 20]
# 5   11    (1, 20]
# 6   92  (80, 100]
# 7   31   (20, 40]
# 8   57   (40, 60]
# 9   42   (40, 60]

# %%
df["age_category"]= pd.cut(x=df['Age'], bins=[1, 20, 40, 60,80, 100],labels=["kids","Young","mid-age","Old","very-old"])   
df
# Out:
#    Age   category age_category
# 0   33   (20, 40]        Young
# 1   67   (60, 80]          Old
# 2   85  (80, 100]     very-old
# 3   32   (20, 40]        Young
# 4   55   (40, 60]      mid-age
# 5   23   (20, 40]        Young
# 6   11    (1, 20]         kids
# 7   93  (80, 100]     very-old
# 8   57   (40, 60]      mid-age
# 9   63   (60, 80]          Old

# %% [markdown]
# Pandas DataFrame.iterrows()
# If you want to loop over the DataFrame for performing some operations on each of the rows then you can use iterrows() function in Pandas.
#
# Pandas use three functions for iterating over the rows of the DataFrame,
#
# i.e., iterrows(), iteritems() and itertuples().
#
# Iterate rows with Pandas iterrows:
#
# The iterrows () is responsible for loop through each row of the DataFrame. It returns an iterator that contains index and data of each row as a Series.
#
# This function returns each index value along with a series that contain the data in each row.
#
# iterrows() - used for iterating over the rows as (index, series) pairs. iteritems() - used for iterating over the (key, value) pairs. itertuples() - used for iterating over the rows as namedtuples.
#
# Yields: index: Returns the index of the row and a tuple for the MultiIndex. data: Returns the data of the row as a Series. it: Returns a generator that iterates over the rows of the frame.

# %%
  
info = pd.DataFrame([[1,2,3],[4,5,8],[34,56,78]],columns = ['col1','col2','col3'])  
info
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     8
# 2    34    56    78

# %%
for i in info:
    print(i)
# Out:
# col1
# col2
# col3

# %%
for i in info["col1"]:
    print(i)
# Out:
# 1
# 4
# 34

# %%
for row_index,row in info.iterrows():
    print(row_index,"---",row)
# Out:
# 0 --- col1    1
# col2    2
# col3    3
# Name: 0, dtype: int64
# 1 --- col1    4
# col2    5
# col3    8
# Name: 1, dtype: int64
# 2 --- col1    34
# col2    56
# col3    78
# Name: 2, dtype: int64

# %%
for row_index,row in info.iterrows():
    print(info[["col1","col3"]].iloc[row_index])
# Out:
# col1    1
# col3    3
# Name: 0, dtype: int64
# col1    4
# col3    8
# Name: 1, dtype: int64
# col1    34
# col3    78
# Name: 2, dtype: int64

# %%
for i in info:  ## gives column names
    print(i)
# Out:
# col1
# col2
# col3

# %%
for row_index,row in info.iterrows():  
    print (row_index,row)
# Out:
# 0 col1    1
# col2    2
# col3    3
# Name: 0, dtype: int64
# 1 col1    4
# col2    5
# col3    8
# Name: 1, dtype: int64
# 2 col1    34
# col2    56
# col3    78
# Name: 2, dtype: int64

# %%
for row_index,row in info.iterrows():  
    print(info[["col1","col3"]].iloc[row_index])
# Out:
# col1    1
# col3    3
# Name: 0, dtype: int64
# col1    4
# col3    8
# Name: 1, dtype: int64
# col1    34
# col3    78
# Name: 2, dtype: int64

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
for ind in tips.index:
    print(tips["smoker"][ind],tips["sex"][ind])
# Out:
# No Female
# No Male
# No Male
# No Male
# No Female
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Female
# No Male
# No Male
# No Female
# No Male
# No Female
# No Male
# No Female
# No Male
# No Male
# No Female
# No Female
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Female
# No Male
# No Male
# No Female
# No Female
# No Male
# No Male
# No Male
# No Female
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Male
# No Female
# No Female
# No Male
# No Male
# No Male
# Yes Male
# No Female
# Yes Male
# No Male
# Yes Male
# Yes Male
# Yes Male
# Yes Male
# No Male
# No Male
# No Female
# Yes Female
# No Male
# Yes Male
# No Male
# No Female
# Yes Female
# Yes Female
# No Female
# No Male
# Yes Male
# No Male
# No Male
# No Male
# Yes Male
# No Male
# No Female
# Yes Male
# No Male
# No Female
# No Male
# No Male
# No Male
# No Male
# Yes Male
# No Male
# Yes Female
# ...

# %%
for i in range(len(df)):
    print(tips.loc[i])
# Out:
# total_bill     16.99
# tip                1
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object
# total_bill     10.34
# tip                1
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 1, dtype: object
# total_bill     21.01
# tip                3
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object
# total_bill     23.68
# tip                3
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object
# total_bill     24.59
# tip                3
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 4, dtype: object
# total_bill     25.29
# tip                4
# sex             Male
# ...

# %%
for i in range(len(df)):
    print(tips.loc[i]["smoker"])
# Out:
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No

# %%
for index, row in tips.iterrows():
    print(index,row)
# Out:
# 0 total_bill     16.99
# tip                1
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object
# 1 total_bill     10.34
# tip                1
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 1, dtype: object
# 2 total_bill     21.01
# tip                3
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object
# 3 total_bill     23.68
# tip                3
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object
# 4 total_bill     24.59
# tip                3
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 4, dtype: object
# 5 total_bill     25.29
# tip                4
# ...

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64
