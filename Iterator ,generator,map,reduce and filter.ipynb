# %% [markdown]
# # Iterators & Generators
# ---

# %% [markdown]
# ## Iterators and generators

# %% [markdown]
# Iterate : to perform a task repeatlty.
# Till now , we have seen with the help of for loop and while loop we can traverse the sequence (list,tuple ) or non -sequence or to handle repeat task.
#
#
# So iterator and genaerator are the tools for traversing the sequence as well.

# %% [markdown]
# ## How loops are used for traversing
#
# ### for loop

# %%
## for traversing sequence
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
## for traversing non sequence
for i in {2:"two",4:"four"}:
    print(i)
# Out:
# 2
# 4

# %%
## using while 
i=0
l=[1,2,3]
while(i<len(l)):
    print(l[i])
    i=i+1
# Out:
# 1
# 2
# 3

# %% [markdown]
# so , it is prettyy much clear that with the helps of loops we can traverse the sequence and non sequence data structure
#
# so question comes >
#
# ### why need iterators and generators if they do same job.
#
#
# ### Beacuse
#
# - They handles large  stream of data (like millions records ) like large file .
# so we can not store all the data in the memory. so we fetch the data in the form of chunks according to requirement.

# %% [markdown]
# ### Iterator
# - iterator is an object which contains a countable numbers of values  and it is used to iterate over iterable objects like list ,tuple etc.
# - iterators mostly used to iterate or convert other objects to an iterator using iter() function
# - iter uses iter() and next() function
# - Every iterator is not a generator

# %% [markdown]
# ## So how to create iterator

# %%
l=[1,2,3,4,5,6,7]
a=iter(l) ## making l as iterator
## a is iterator object  at memory location
a

# %%
type(a)
# Out:
# list_iterator

# %%
a

# %% [markdown]
# ## Fetching the data of above iterator using next()

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 2

# %%
next(a)
# Out:
# 3

# %%
next(a)
# Out:
# 4

# %%
next(a)
# Out:
# 5

# %%
next(a)
# Out:
# 6

# %% [markdown]
# It does not give the all elements in one short . Rather it gives the data until we ask for it. this phenomena is called as lazy evalauator
#
#
# since it does not give until we ask for it. becoz of this lazy evalutaion iterators helps us to deal with infinite long iterables .

# %% [markdown]
# ### iterable vs iterator
#
#
# ### iterator : object which iterates over iterable
#
#
#
# ### iterable: object over which we are able to iterate. means capable of returning numbers one by one.
#     eg : built in sequence : like list ,tuple
#          built in non sequence - dict

# %% [markdown]
# ### iter() and next() built-in functions
# A key to fully understand generators is the next() and the iter() function.
#
# The next function allows us to access the next element in a sequence. Let's check how it works.

# %% [markdown]
# ### Generators: It is special kind of function  which returns iterators by using yield keyword.
# - generators are an iterators which can execute only once.
# - Generators use yield keywords.
# - Generators are mostly used in loops for generate an iterator by returning all the values in the loop
# - Every generator is an iterator

# %% [markdown]
# eg : we have function whose taks is to read the content of file . what if the file sze is large than available memory so make it a generator functions and read the data in chunks.

# %% [markdown]
# def reading("file_name"):
#
#     obj=csn_reader("abc.txt")
#
#     for row in obj:
#
#         yeild row

# %% [markdown]
# ### This function is responsible to generate the cube of numbers with in specified range.

# %%
l=[]
def fun(num):
    for i in range(num):
        print("hi")
        yield i*3
        print("hello")
fun(6)
# Out:
# <generator object fun at 0x000001F10A466F90>

# %%
y=fun(6)
#y=iter(x) # Making an in terator
next(y)
# Out:
# hi
# 0

# %%
next(y)
# Out:
# hello
# hi
# 3

# %%
next(y)
# Out:
# hello
# hi
# 6

# %%
next(y)
# Out:
# hello
# hi
# 9

# %%
next(y)
# Out:
# hello
# hi
# 12

# %%
next(y)
# Out:
# hello
# hi
# 15

# %%
next(y)
# Out:
# hello
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 next(y)
#
# StopIteration:

# %% [markdown]
# #### Finally, when the function terminates, StopIteration is raised automatically on further calls.
# next(a)

# %% [markdown]
# ### #### Note
# - generators can be only make from yield keyword
# - Yield=>Yield is a keyword in Python that is used to return from a function without destroying the states of its local variable
#
#
# ### return vs yeild
#
# yeild basically suspends the function while return exit the function
#
# return would be last statement and yield may or may not.

# %%
## return: once return is encoutered following statements wont be executed while in case of yield following statements can be read.
def abc():
    print("hi")
    return 2
    print( "hello")
k=abc()
print(k)
# Out:
# hi
# 2

# %%
# A simple generator function
def my_gen():
    n = 1
    print('This is printed first')
    # Generator function contains yield statements
    yield n

    n += 1
    print('This is printed second')
    yield n

    n += 1
    print('This is printed at last')
    yield n
    
# It returns an object but does not start execution immediately.
a = my_gen()

# %%
# We can iterate through the items using next().
next(a)
# Out:
# This is printed first
# 1

# %%
# Local variables and theirs states are remembered between successive calls.
next(a)
# Out:
# This is printed second
# 2

# %%
next(a)
# Out:
# This is printed at last
# 3

# %% [markdown]
# ### lambda (Annonymous Function)
# - These functions are called anonymous because they are not declared in the standard manner by using the def keyword.
# - You can use the lambda keyword to create small anonymous functions.

# %% [markdown]
# ### It is a keyword which act as a anonymous function. Anonymous means.(function without name)
#
#
# ### It is that function which can take any number of arguments but has only one expression

# %% [markdown]
# ### Applications

# %% [markdown]
# - 1 It is use when you need to use the function one time, no need to define the functions with proper retun statement ,here     it contains an expression that is returned.
#
# - 2. It is good for simple logical operations that are easy to understand. (readibility)
#
# - 3.  It is also used when we pass the argument as function to higher order function eg : filter,map.

# %% [markdown]
# ### Cons
#
# 1- It is considered as bad when you are required to perform more than one independent operations
#
# 2. u can't write doc string to explain function taks

# %% [markdown]
# ### Syntax
# - The syntax of lambda functions contains only a single statement.
# - lambda [arg1 [,arg2,.....argn]]:expression

# %% [markdown]
# ### waf to give sum of two numbers.

# %%
def add(a,b):
    c=a+b
    return c
add(2,3)
# Out:
# 5

# %%
lambda a1,a2:a1+a2
# Out:
# <function __main__.<lambda>(a1, a2)>

# %%
type(lambda a1,a2:a1+a2)
# Out:
# function

# %%
(lambda a1,a2:a1+a2)(2,3)
# Out:
# 5

# %%
(lambda a1,a2:a1+a2)(int(input("enter the first number")),int(input("enter the second number")))
# Out:
# enter the first number4
# enter the second number5
# 9

# %%
k=(lambda a1,a2:a1+a2)
k
# Out:
# <function __main__.<lambda>(a1, a2)>

# %%
k(2,3)
# Out:
# 5

# %%
k(5,6)
# Out:
# 11

# %% [markdown]
# ### using lambda

# %%
(lambda a,b:a+b)
# Out:
# <function __main__.<lambda>(a, b)>

# %%
type((lambda a,b:a+b))
# Out:
# function

# %%
(lambda a,b:a+b)(2,3)
# Out:
# 5

# %%
sum1=(lambda a,b:a+b)(2,3)
sum1
# Out:
# 5

# %%
sum1
# Out:
# 5

# %%
##  Addition from lambda
result=(lambda a,b:a+b)
print(result(2,3))
# first we assign a two variables a,b then seperated by colon lambda func that performed a+b
# Out:
# 5

# %%
result(4,3)
# Out:
# 7

# %% [markdown]
# or

# %%
##  Addition from lambda
result=(lambda a,b:a+b)(2,3)
print(result)
# first we assign a two variables a,b then seperated by colon lambda func that performed a+b
# Out:
# 5

# %%
#Example 2 finding greatest number from lambda
max_number=(lambda x,y: x if x>y else y)(int(input()),int(input()))
max_number
# first we assign a two variables x,y then seperated by colon and apply the conditon whcih one is greater betwwn x & y with the help of lambda func
# Out:
# 3
# 4
# 4

# %% [markdown]
# ### wap to find given strings starts with given character using lambda.

# %%
s="madrid"
k=(lambda x:x if x.startswith("m") else "")
print(k(s))
# Out:
# madrid

# %% [markdown]
# ### waf to check whether the fruit name startswith "a" without lambda or with lambda

# %%
def fruit_check(fruit):
    if fruit.startswith("a"):
        print(fruit)

# %%
fruit_check("apple")
# Out:
# apple

# %%
(lambda fruit: fruit if fruit.startswith("a") else "")("apple")
# Out:
# 'apple'

# %%
f=lambda fruit: fruit if fruit.startswith("a") else ""
f
# Out:
# <function __main__.<lambda>(fruit)>

# %%
f("cheerry")
# Out:
# ''

# %% [markdown]
# ### WAP if given string is number or not using lambda.

# %%
s=input("enter the number")
r=(lambda x:"number" if type(x)==int else "string")
print(r(s))
# Out:
# enter the number234
# string

# %% [markdown]
# ### WAP to sort the dictionary using values

# %%
d={"one":1,"five":5,"two":2}
print(d.items())
sorted_dt=sorted(d.items(), key=lambda item: item[1])  ## item[1] means second lement of tuple
print(sorted_dt)
# Out:
# dict_items([('one', 1), ('five', 5), ('two', 2)])
# [('one', 1), ('two', 2), ('five', 5)]

# %% [markdown]
# ## WAP to sort the dictionary using keys

# %%
d={"one":1,"five":5,"two":2}
sorted_dt=sorted(d.items(), key=lambda item: item[0])
print(sorted_dt)
# Out:
# [('five', 5), ('one', 1), ('two', 2)]

# %%
d={"one":1,"five":5,"two":2}
print(d)
sorted_dt=sorted(d) #by default by keys
print(sorted_dt)
# Out:
# {'one': 1, 'five': 5, 'two': 2}
# ['five', 'one', 'two']

# %% [markdown]
# #### Map()
# - The map() function iterates through all items in the given iterable and executes the function we passed as an argument on each of them

# %% [markdown]
# ### Why we need map?

# %%
### to get those fruits name starts with "a"
l=["apple","avacado","banana","cherry"]
l1=[]
for i in l:
    if i.startswith("a"):
        l1.append(i)
print(l1)
# Out:
# ['apple', 'avacado']

# %%
## or using list comprehension
fruits=["apple","avacado","banana","cherry"]
l=[i for i in fruits  if i.startswith("a")]
print(l)
# Out:
# ['apple', 'avacado']

# %%
fruits=["apple","avacado","banana","cherry"]

# %%
def fruit_check(fruit):
    if fruit.startswith("a"):
        return fruit
    else:
        return ""

# %%
list(map(fruit_check,fruits))
# Out:
# ['apple', 'avacado', '', '']

# %%
a=map(lambda fruit: fruit if fruit.startswith("a") else "",fruits)
a

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 next(a)
#
# StopIteration:

# %%
def start(x1):
    if x1.startswith("a"):
        return x1
    else:
        return ""

# %%
list(map(start,fruits))
# Out:
# ['apple', 'avacado', '', '']

# %%
a=map((lambda x: x if x.startswith("a") else ""),fruits)
a

# %%
type(a)
# Out:
# map

# %%
list(a)
# Out:
# ['apple', 'avacado', '', '']

# %%
next(a)
# Out:
# 'apple'

# %% [markdown]
# ### map is a faster way to do above task without using loop

# %%
fruits=["apple","avacado","banana","cherry"]
a=map((lambda x:x if x.startswith("a") else ""),fruits)  ## it returns the iterator 
a

# %%
next(a)
# Out:
# 'apple'

# %%
next(a)
# Out:
# 'avacado'

# %%
next(a)
# Out:
# ''

# %%
next(a)
# Out:
# ''

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 next(a)
#
# StopIteration:

# %%
l=list(map((lambda x:x if x.startswith("a") else ""),fruits))
l
# Out:
# ['apple', 'avacado', '', '']

# %% [markdown]
# ### so what map does : it applies the functionalites to each elemen tof list
#
# ### here we define the functionalies of single element map maps this to each element of list

# %% [markdown]
# syntax : map(function,sequence1,sequence 2...)

# %%
#Write a Python program to triple all numbers of a given list of integers. Use Python map and lambda
l=[1,4,5,6]
triple=list(map(lambda x:3*x,l))
print(triple)
# Out:
# [3, 12, 15, 18]

# %% [markdown]
# ## wap
# l1=[12,3,4]
# l2=[2,3,4]
# l=[14, 6, 8]

# %%
l1=[12,3,4]
l2=[2,3,4]
k=list(zip(l1,l2))
k
# Out:
# [(12, 2), (3, 3), (4, 4)]

# %%
l=[]
for i in k:
    s=i[0]+i[1]
    l.append(s)
l
# Out:
# [14, 6, 8]

# %%
list(map(lambda x,y:x+y,l1,l2))
# Out:
# [14, 6, 8]

# %%
l1=[12,3,4]
l2=[2,3,4]
list(map(lambda x,y:x+y,l1,l2))
# Out:
# [14, 6, 8]

# %%
#Write a Python program to add two given lists and find the difference between lists. Use map() function 
l1=[2,3,4]
l2=[5,6,7]
def add(x,y):
    s=x+y
    return s
l=list(map(add,l1,l2))
print(l)
# Out:
# [7, 9, 11]

# %%
fruits=["apple","avacado","cheery"]
l=[]
for i in fruits:
    if i.startswith("a"):
        l.append(i)
    else:
        l.append(" ")
l
# Out:
# ['apple', 'avacado', ' ']

# %%
[i for i in fruits if i.startswith("a") ]
# Out:
# ['apple', 'avacado']

# %%
fruits=["apple","avacado","banana","cherry"]
list(map((lambda x:x if x.startswith("a") else ""),fruits))
# Out:
# ['apple', 'avacado', '', '']

# %%
### using lambda
l1=[2,3,4]
l2=[5,6,7]
l=list(map(lambda x,y:x+y,l1,l2))
print(l)
# Out:
# [7, 9, 11]

# %%
#Write a Python program to add three given lists using Python map and lambd
l=["blue","red"]
result=list(map(lambda x:list(x),l))
print(result)
# Out:
# [['b', 'l', 'u', 'e'], ['r', 'e', 'd']]

# %%
'''WAP to print the power of numbers . by taking a list of bases and a list of raised powers .
'''
base_list=[2,4,6]
power_list=[2,3,1]
def num_power(base,power):
    result=base**power
    return result
a=list(map(num_power,base_list,power_list))
print("power of numbers lists ", a)
# Out:
# power of numbers lists  [4, 64, 6]

# %%
list(map(lambda b,p:b**p,base_list,power_list))
# Out:
# [4, 64, 6]

# %%
'''WAP to print the power of numbers . by taking a list of bases and a list of raised powers . 
with lamba
'''
base_list=[2,4,6]
power_list=[2,3,1]
a=list(map(lambda base,power: base**power,base_list,power_list))
print(a)
# Out:
# [4, 64, 6]

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c = [9,10,11,12]

list(map(lambda x,y,z : x+y+z ,a,b,c))
# Out:
# [15, 18, 21, 24]

# %% [markdown]
# ### Filter()
# - filter forms a new list which can contain only those elements that satisfies the certain condition(filtering critera)

# %%
## wap to exract the list of fruits that starts with a

# %%
fruits=["apple","avacado","banana","cherry"]
list(map((lambda x:x if x.startswith("a") else ""),fruits))
# Out:
# ['apple', 'avacado', '', '']

# %%
list(filter((lambda fruit: fruit if fruit.startswith("a") else ""),fruits))
# Out:
# ['apple', 'avacado']

# %%
fruits=["apple","avacado","banana","cherry"]
list(filter((lambda x:x if x.startswith("a") else ""),fruits))
# Out:
# ['apple', 'avacado']

# %% [markdown]
# ### In filter , we extract the output where function condition is met (true) not het outout on others unlike in map.

# %%
## Note both filter and map returns the iterator . we can extract the item using next ()

# %%
fruits=["apple","avacado","banana","cherry"]
a=(map((lambda x:x if x.startswith("a") else ""),fruits))
a

# %%
next(a)
# Out:
# 'apple'

# %%
next(a)
# Out:
# 'avacado'

# %%
def double(n):
    return n*2
l=[1,2,3,4]
k=list(map(double,l))
k
# Out:
# [2, 4, 6, 8]

# %%
l=[1,2,3,4]

# %%
list(map(lambda x: x*2,l))
# Out:
# [2, 4, 6, 8]

# %%
list(filter(lambda x:x*2,l))
# Out:
# [1, 2, 3, 4]

# %%
def double(n):
    return n*2
l=[1,2,3,4]
k=list(filter(double,l))
k  ## since double is not conditional based
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Reduce()
# - Reduce function works differently than map() and fillter(). it does not return a new datastype list of tuple like a map and fillter.it returns only a single value
# - Reduce can be found in functools module()

# %% [markdown]
# ![Capture.4PNG.PNG](attachment:Capture.4PNG.PNG)

# %%
from functools import reduce
li=[47,11,42,13]
# Returns the sum of all the elements using `reduce`
reduce(lambda a,b:a if a>b else b,li)
# Out:
# 47

# %%
# Find the largest value in the list

# %%
reduce(lambda x,y: x if x>y else y,li)
# Out:
# 47
